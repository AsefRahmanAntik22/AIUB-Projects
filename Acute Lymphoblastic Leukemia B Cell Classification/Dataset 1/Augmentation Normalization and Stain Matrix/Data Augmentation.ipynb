# %%
# !python -m pip install imgaug
# Out:
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (1.26.4)
# Requirement already satisfied: scipy in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (1.14.1)
# Requirement already satisfied: Pillow in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (3.10.0)
# Collecting scikit-image>=0.14.2 (from imgaug)
#   Downloading scikit_image-0.25.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: opencv-python in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from imgaug) (4.10.0.84)
# Collecting imageio (from imgaug)
#   Downloading imageio-2.36.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting Shapely (from imgaug)
#   Downloading shapely-2.0.6-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Collecting networkx>=3.0 (from scikit-image>=0.14.2->imgaug)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.14.2->imgaug)
#   Downloading tifffile-2024.12.12-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from scikit-image>=0.14.2->imgaug) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.14.2->imgaug)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\faysal ahmmed\.conda\envs\py310\lib\site-packages (from matplotlib->imgaug) (2.9.0.post0)
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.0 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/948.0 kB 932.9 kB/s eta 0:00:01
#    ---------------------------------------- 948.0/948.0 kB 1.1 MB/s eta 0:00:00
# Downloading scikit_image-0.25.0-cp310-cp310-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.8 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/12.8 MB 2.2 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.8 MB 2.3 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.8 MB 2.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.8 MB 2.7 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.8 MB 2.9 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.8 MB 3.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.8 MB 3.4 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.8 MB 3.5 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.8 MB 3.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.8 MB 3.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 3.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.8 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 3.7 MB/s eta 0:00:00
# Downloading imageio-2.36.1-py3-none-any.whl (315 kB)
# Downloading shapely-2.0.6-cp310-cp310-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------------- ---------- 1.0/1.4 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.7 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.0 MB/s eta 0:00:00
# Downloading tifffile-2024.12.12-py3-none-any.whl (227 kB)
# Installing collected packages: tifffile, Shapely, networkx, lazy-loader, imageio, scikit-image, imgaug
# Successfully installed Shapely-2.0.6 imageio-2.36.1 imgaug-0.4.0 lazy-loader-0.4 networkx-3.4.2 scikit-image-0.25.0 tifffile-2024.12.12

# %%
import os
import random
import numpy as np
from PIL import Image
import imgaug.augmenters as iaa

# Path to your dataset folder
dataset_path = "normalized_output of Blood Cancer2 vahadane"
target_count = 2000  # Target number of images per folder

augmenters = iaa.Sequential([
    iaa.Fliplr(0.5),  # Horizontal flip
    iaa.Flipud(0.1),  # Vertical flip
    iaa.Affine(
        scale=(0.95, 1.05),
        rotate=(-10, 10),
        shear=(-5, 5),
        mode='edge',  # Use edge pixel padding instead of black
        cval=0  # You can also try values like 128 or 255 for different backgrounds
    ),
    iaa.Crop(percent=(0, 0.05), keep_size=True),
])

# Function to save augmented images
def save_augmented_images(folder_path, images, augmenter, target):
    current_count = len(images)
    original_image = Image.open(images[0])
    original_size = original_image.size  # Preserve original dimensions

    while current_count < target:
        # Randomly choose an image
        img_path = random.choice(images)
        img = Image.open(img_path)
        img_array = np.array(img, dtype=np.uint8)
        
        # Apply augmentation
        augmented_image_array = augmenter(image=img_array)
        augmented_image = Image.fromarray(augmented_image_array).resize(original_size, Image.Resampling.LANCZOS)
        
        # Save the augmented image with high quality
        new_filename = os.path.join(folder_path, f"aug_{current_count}.jpg")
        augmented_image.save(new_filename, quality=100)  # Save with perfect quality
        
        current_count += 1

# Detect folders in the dataset directory
folders = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]

# Augment images for each detected folder
for folder in folders:
    folder_path = os.path.join(dataset_path, folder)
    images = [os.path.join(folder_path, img) for img in os.listdir(folder_path) if img.endswith(('.png', '.jpg', '.jpeg'))]
    
    # Perform augmentation if needed
    if len(images) < target_count:
        print(f"Augmenting {folder} from {len(images)} to {target_count} images.")
        save_augmented_images(folder_path, images, augmenters, target_count)
    else:
        print(f"{folder} already has {len(images)} images or more.")

print("Data augmentation completed!")
# Out:
# Augmenting Benign from 512 to 2000 images.
# Augmenting [Malignant] early Pre-B from 979 to 2000 images.
# Augmenting [Malignant] Pre-B from 955 to 2000 images.
# Augmenting [Malignant] Pro-B from 796 to 2000 images.
# Data augmentation completed!
