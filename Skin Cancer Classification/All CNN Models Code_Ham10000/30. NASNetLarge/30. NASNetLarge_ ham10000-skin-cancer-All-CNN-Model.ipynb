# %%
# Only need to change here to load your desire model for the entire code
from tensorflow.keras.applications.nasnet import preprocess_input
from tensorflow.keras.applications import NASNetLarge
model_name = "NASNetLarge"

# %%
# === System & OS Utilities ===
import os
import random
import math
import pickle
import sys
import warnings
warnings.filterwarnings("ignore")

# === Progress Bar ===
from tqdm import tqdm

# === TensorFlow & Keras ===
import tensorflow as tf
from tensorflow.keras.models import Model, load_model

from tensorflow.keras.layers import (
    Layer, Conv2D, Dense, Dropout,
    GlobalAveragePooling2D, GlobalMaxPooling2D,
    Reshape, Multiply, Add, Activation, Concatenate
)
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras import Input

# === Data Handling ===
import numpy as np
import pandas as pd
import cv2

# === Visualization ===
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# === Scikit-learn ===
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report, roc_auc_score
)

# %%
print("Python version:", sys.version)
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("OpenCV version:", cv2.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Python version: 3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]
# TensorFlow version: 2.10.1
# Keras version: 2.10.0
# NumPy version: 1.26.4
# Pandas version: 2.2.3
# OpenCV version: 4.11.0
# Matplotlib version: 3.10.3
# Seaborn version: 0.13.2
# Scikit-learn version: 1.6.1

# %% [markdown]
# > You need to install specific versions of library given below to work with this notebook
#
# The given command will install the following versions:
#
# * Python: 3.11.11 (as per your system)
#
# * TensorFlow: 2.18.0
#
# * Keras: 3.5.0
#
# * NumPy: 1.26.4
#
# * Pandas: 2.2.3
#
# * OpenCV: 4.6.0.66
#
# * Matplotlib: 3.7.5
#
# * Seaborn: 0.12.2
#
# * Scikit-learn: 1.2.2

# %%
#python version 3.11.11
#!>python -m pip install tensorflow==2.18.0 keras==3.5.0 numpy==1.26.4 pandas==2.2.3 opencv-python==4.6.0.66 matplotlib==3.7.5 seaborn==0.12.2 scikit-learn==1.2.2

# %%
# For Windows to use graphics card (GPU) install these version
# Remember These versions are used for ALL_CNN_Models_Evaluation except Proposed Model
"""   
conda create -n py310 python=3.10
conda active py310
conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
python -m pip install "tensorflow<2.11" "numpy<2.0" opencv-python matplotlib scikit-learn pandas seaborn tqdm
"""
# Out:
# '   \nconda create -n py310 python=3.10\nconda active py310\nconda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0\npython -m pip install "tensorflow<2.11" "numpy<2.0" opencv-python matplotlib scikit-learn pandas seaborn tqdm\n'

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPUs detected: {len(gpus)}")
    except RuntimeError as e:
        print(f"Error setting GPU memory growth: {e}")
else:
    print("No GPUs detected.")
# Out:
# GPUs detected: 1

# %%
BATCH_SIZE = 16
IMG_SIZE = (224, 224)
EPOCH = 20
img_shape=(*IMG_SIZE,3)
labels = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#labels = ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'UNK', 'VASC']

# %%
def data_frame(path):
    class_paths = []
    classes = []

    for label in os.listdir(path):
        class_dir = os.path.join(path, label)
        if os.path.isdir(class_dir):  
            for image in os.listdir(class_dir):
                class_paths.append(os.path.join(class_dir, image))
                classes.append(label)

    df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return df

# %%
#dataframe = data_frame('/kaggle/input/ham1000-aug-resized-organized/HAM10000_organized')
dataframe = data_frame(r"C:\Users\Antik\OneDrive - American International University-Bangladesh\Desktop\Skin Cancer Thesis Final Codes\Other Models\HAM10000_organized")
# First split: 70% train, 30% temp (val + test)
train_dataframe, temp_dataframe = train_test_split(
    dataframe,
    test_size=0.3,
    random_state=42,
    stratify=dataframe['Class']
)

# Second split: 2/3 val, 1/3 test of the 30% => 20% val, 10% test overall
validation_dataframe, test_dataframe = train_test_split(
    temp_dataframe,
    test_size=1/3,
    random_state=42,
    stratify=temp_dataframe['Class']
)

print(f"Train size: {len(train_dataframe)}, Validation size: {len(validation_dataframe)}, Test size: {len(test_dataframe)}")
# Out:
# Train size: 32854, Validation size: 9387, Test size: 4694

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)


train_data = train_datagen.flow_from_dataframe(train_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, seed=42)

validation_data = val_datagen.flow_from_dataframe(validation_dataframe, x_col='Class Path',
                                     y_col='Class', batch_size=BATCH_SIZE,
                                     target_size=IMG_SIZE, seed=42)

test_data = test_datagen.flow_from_dataframe(test_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, shuffle=False, seed=42)
# Out:
# Found 32854 validated image filenames belonging to 7 classes.
# Found 9387 validated image filenames belonging to 7 classes.
# Found 4694 validated image filenames belonging to 7 classes.

# %%
@tf.keras.utils.register_keras_serializable(package="Custom", name="F1Score")
class F1Score(tf.keras.metrics.Metric):
    """
    Custom Keras metric to compute the F1 Score.
    The F1 score is the harmonic mean of precision and recall.
    """

    def __init__(self, name='f1_score', **kwargs):
        """
        Initializes the F1Score metric. 
        - Uses Keras' Precision and Recall metrics as intermediate steps.
        """
        super().__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()  # Precision metric
        self.recall = tf.keras.metrics.Recall()  # Recall metric

    def update_state(self, y_true, y_pred, sample_weight=None):
        """
        Updates the state of the metric.
        - This method is called during training to update precision and recall.
        - The precision and recall states are updated based on true and predicted values.
        """
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        """
        Computes and returns the F1 score.
        - F1 score is calculated as the harmonic mean of precision and recall.
        - Prevents division by zero by adding a small epsilon value to the denominator.
        """
        p = self.precision.result()  # Get precision value
        r = self.recall.result()  # Get recall value
        return 2 * (p * r) / (p + r + tf.keras.backend.epsilon())  # Calculate F1 score

    def reset_states(self):
        """
        Resets the states of the precision and recall metrics.
        - This is called at the beginning of each epoch.
        """
        self.precision.reset_states()  # Reset precision state
        self.recall.reset_states()  # Reset recall state

# %%
class RestoreBestValidationModel(Callback):
    """
    Custom Keras Callback to restore model weights from the best epoch based on validation accuracy.
    - Tracks the best validation accuracy during training.
    - Restores the model weights from the epoch with the best validation accuracy when training finishes.
    """
    
    def __init__(self):
        super(RestoreBestValidationModel, self).__init__()
        # Initialize best validation accuracy, epoch, and weights to track the best model
        self.best_val_acc = -1
        self.best_epoch = -1
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        """
        Callback function executed at the end of each epoch.
        - Compares the current validation accuracy with the best validation accuracy.
        - If the current validation accuracy is higher or tied but at a later epoch, updates the best model weights.
        """
        # Get validation accuracy from logs
        val_acc = logs.get('val_accuracy')
        
        if val_acc is not None:
            # Update the best validation accuracy and weights if the current one is better or at a later epoch
            if val_acc > self.best_val_acc or (val_acc == self.best_val_acc and epoch > self.best_epoch):
                self.best_val_acc = val_acc
                self.best_epoch = epoch
                self.best_weights = self.model.get_weights()  # Store the model's weights
                print(f"Model weights updated at epoch {epoch + 1} with val_accuracy: {val_acc:.4f}")

    def on_train_end(self, logs=None):
        """
        Callback function executed at the end of training.
        - Restores the model weights from the epoch with the best validation accuracy.
        """
        # If we found a better model during training, restore the best weights
        if self.best_weights is not None:
            print(f"Restoring model weights from best epoch {self.best_epoch + 1} with val_accuracy: {self.best_val_acc:.4f}")
            self.model.set_weights(self.best_weights)  # Set the weights back to the best model's weights

# Instantiate the callback
restore_best = RestoreBestValidationModel()

# %%
# 1. Define input shape
input_tensor = Input(shape=(224, 224, 3))

# 2. Load base model dynamically without top (classification head)
# Warning-Eval is a dangerous function.
base_model = eval(f"{model_name}(weights='imagenet', include_top=False, input_tensor=input_tensor)")

# 3. Freeze base model layers (optional, if you don't want them to train initially)
base_model.trainable = False

# 4. Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(len(labels), activation='softmax')(x)  

# 5. Build final model
model = Model(inputs=base_model.input, outputs=output)

# 6. Compile the model
# Categorical cross-entropy loss is used for multi-class classification.
# Additional metrics: accuracy, precision, recall, F1 score, and AUC (Area Under the Curve).
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
               metrics=['accuracy', 
                        Precision(name='precision'), 
                        Recall(name='recall'),
                        F1Score(),
                        AUC(name='auc')])

# Print the model summary to check the architecture.
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 115s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv1 (Conv2D)            (None, 111, 111, 96  2592        ['input_1[0][0]']
#                                 )
#
#  stem_bn1 (BatchNormalization)  (None, 111, 111, 96  384         ['stem_conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 111, 111, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_conv_1_stem_1 (Conv2  (None, 111, 111, 42  4032       ['activation[0][0]']
#  D)                             )
#
#  reduction_bn_1_stem_1 (BatchNo  (None, 111, 111, 42  168        ['reduction_conv_1_stem_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 111, 111, 42  0           ['reduction_bn_1_stem_1[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 111, 111, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 42  0          ['activation_1[0][0]']
#  _left1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 96  0          ['activation_3[0][0]']
#  _right1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 42)  2814        ['separable_conv_1_pad_reduction_
#  t1_stem_1 (SeparableConv2D)                                     left1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht1_stem_1 (SeparableConv2D)                                    right1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_1_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_1_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 56, 56, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_1[0][0]']
#
#  activation_4 (Activation)      (None, 56, 56, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 42)  2814        ['activation_2[0][0]']
#  t1_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 42)  3822        ['activation_4[0][0]']
#  ht1_stem_1 (SeparableConv2D)
#
#  activation_5 (Activation)      (None, 111, 111, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_2_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_2_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 96  0          ['activation_5[0][0]']
#  _right2_stem_1 (ZeroPadding2D)  )
#
#  activation_7 (Activation)      (None, 111, 111, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_add_1_stem_1 (Add)   (None, 56, 56, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht2_stem_1 (SeparableConv2D)                                    right2_stem_1[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 96  0          ['activation_7[0][0]']
#  _right3_stem_1 (ZeroPadding2D)  )
#
#  activation_9 (Activation)      (None, 56, 56, 42)   0           ['reduction_add_1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_1_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 42)  6432        ['separable_conv_1_pad_reduction_
#  ht3_stem_1 (SeparableConv2D)                                    right3_stem_1[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 42)  2142        ['activation_9[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  activation_6 (Activation)      (None, 56, 56, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_1_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_1_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_pad_1_stem_1 (ZeroPa  (None, 113, 113, 42  0          ['reduction_bn_1_stem_1[0][0]']
#  dding2D)                       )
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 42)  3822        ['activation_6[0][0]']
#  ht2_stem_1 (SeparableConv2D)
#
#  activation_8 (Activation)      (None, 56, 56, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  activation_10 (Activation)     (None, 56, 56, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (MaxPoo  (None, 56, 56, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_2_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 42)  2814        ['activation_8[0][0]']
#  ht3_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 42)  2142        ['activation_10[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  adjust_relu_1_stem_2 (Activati  (None, 111, 111, 96  0          ['stem_bn1[0][0]']
#  on)                            )
#
#  reduction_add_2_stem_1 (Add)   (None, 56, 56, 42)   0           ['reduction_left2_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Averag  (None, 56, 56, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_2_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  reduction_left4_stem_1 (Averag  (None, 56, 56, 42)  0           ['reduction_add_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 42)  168         ['separable_conv_2_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_right5_stem_1 (MaxPo  (None, 56, 56, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  oling2D)
#
#  zero_padding2d (ZeroPadding2D)  (None, 112, 112, 96  0          ['adjust_relu_1_stem_2[0][0]']
#                                 )
#
#  reduction_add3_stem_1 (Add)    (None, 56, 56, 42)   0           ['reduction_left3_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  add (Add)                      (None, 56, 56, 42)   0           ['reduction_add_2_stem_1[0][0]',
#                                                                   'reduction_left4_stem_1[0][0]']
#
#  reduction_add4_stem_1 (Add)    (None, 56, 56, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_1[0][0]',
#                                                                   'reduction_right5_stem_1[0][0]']
#
#  cropping2d (Cropping2D)        (None, 111, 111, 96  0           ['zero_padding2d[0][0]']
#                                 )
#
#  reduction_concat_stem_1 (Conca  (None, 56, 56, 168)  0          ['reduction_add_2_stem_1[0][0]',
#  tenate)                                                          'reduction_add3_stem_1[0][0]',
#                                                                   'add[0][0]',
#                                                                   'reduction_add4_stem_1[0][0]']
#
#  adjust_avg_pool_1_stem_2 (Aver  (None, 56, 56, 96)  0           ['adjust_relu_1_stem_2[0][0]']
#  agePooling2D)
#
#  adjust_avg_pool_2_stem_2 (Aver  (None, 56, 56, 96)  0           ['cropping2d[0][0]']
#  agePooling2D)
#
#  activation_11 (Activation)     (None, 56, 56, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  adjust_conv_1_stem_2 (Conv2D)  (None, 56, 56, 42)   4032        ['adjust_avg_pool_1_stem_2[0][0]'
#                                                                  ]
#
#  adjust_conv_2_stem_2 (Conv2D)  (None, 56, 56, 42)   4032        ['adjust_avg_pool_2_stem_2[0][0]'
#                                                                  ]
#
#  reduction_conv_1_stem_2 (Conv2  (None, 56, 56, 84)  14112       ['activation_11[0][0]']
#  D)
#
#  concatenate (Concatenate)      (None, 56, 56, 84)   0           ['adjust_conv_1_stem_2[0][0]',
#                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (BatchNo  (None, 56, 56, 84)  336         ['reduction_conv_1_stem_2[0][0]']
#  rmalization)
#
#  adjust_bn_stem_2 (BatchNormali  (None, 56, 56, 84)  336         ['concatenate[0][0]']
#  zation)
#
#  activation_12 (Activation)     (None, 56, 56, 84)   0           ['reduction_bn_1_stem_2[0][0]']
#
#  activation_14 (Activation)     (None, 56, 56, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 84)  0           ['activation_12[0][0]']
#  _left1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 84)  0           ['activation_14[0][0]']
#  _right1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 84)  9156        ['separable_conv_1_pad_reduction_
#  t1_stem_2 (SeparableConv2D)                                     left1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht1_stem_2 (SeparableConv2D)                                    right1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_1_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_1_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_2[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 84)  9156        ['activation_13[0][0]']
#  t1_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 84)  11172       ['activation_15[0][0]']
#  ht1_stem_2 (SeparableConv2D)
#
#  activation_16 (Activation)     (None, 56, 56, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_2_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_2_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 84)  0           ['activation_16[0][0]']
#  _right2_stem_2 (ZeroPadding2D)
#
#  activation_18 (Activation)     (None, 56, 56, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Add)   (None, 28, 28, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht2_stem_2 (SeparableConv2D)                                    right2_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 84)  0           ['activation_18[0][0]']
#  _right3_stem_2 (ZeroPadding2D)
#
#  activation_20 (Activation)     (None, 28, 28, 84)   0           ['reduction_add_1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_1_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 84)  9156        ['separable_conv_1_pad_reduction_
#  ht3_stem_2 (SeparableConv2D)                                    right3_stem_2[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 84)  7812        ['activation_20[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  activation_17 (Activation)     (None, 28, 28, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_1_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_1_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_pad_1_stem_2 (ZeroPa  (None, 57, 57, 84)  0           ['reduction_bn_1_stem_2[0][0]']
#  dding2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 84)  11172       ['activation_17[0][0]']
#  ht2_stem_2 (SeparableConv2D)
#
#  activation_19 (Activation)     (None, 28, 28, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (MaxPoo  (None, 28, 28, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_2_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 84)  9156        ['activation_19[0][0]']
#  ht3_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 84)  7812        ['activation_21[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  adjust_relu_1_0 (Activation)   (None, 56, 56, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  reduction_add_2_stem_2 (Add)   (None, 28, 28, 84)   0           ['reduction_left2_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Averag  (None, 28, 28, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_2_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  reduction_left4_stem_2 (Averag  (None, 28, 28, 84)  0           ['reduction_add_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 84)  336         ['separable_conv_2_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_right5_stem_2 (MaxPo  (None, 28, 28, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  oling2D)
#
#  zero_padding2d_1 (ZeroPadding2  (None, 57, 57, 168)  0          ['adjust_relu_1_0[0][0]']
#  D)
#
#  reduction_add3_stem_2 (Add)    (None, 28, 28, 84)   0           ['reduction_left3_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 84)   0           ['reduction_add_2_stem_2[0][0]',
#                                                                   'reduction_left4_stem_2[0][0]']
#
#  reduction_add4_stem_2 (Add)    (None, 28, 28, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_2[0][0]',
#                                                                   'reduction_right5_stem_2[0][0]']
#
#  cropping2d_1 (Cropping2D)      (None, 56, 56, 168)  0           ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (Conca  (None, 28, 28, 336)  0          ['reduction_add_2_stem_2[0][0]',
#  tenate)                                                          'reduction_add3_stem_2[0][0]',
#                                                                   'add_1[0][0]',
#                                                                   'reduction_add4_stem_2[0][0]']
#
#  adjust_avg_pool_1_0 (AveragePo  (None, 28, 28, 168)  0          ['adjust_relu_1_0[0][0]']
#  oling2D)
#
#  adjust_avg_pool_2_0 (AveragePo  (None, 28, 28, 168)  0          ['cropping2d_1[0][0]']
#  oling2D)
#
#  adjust_conv_1_0 (Conv2D)       (None, 28, 28, 84)   14112       ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)       (None, 28, 28, 84)   14112       ['adjust_avg_pool_2_0[0][0]']
#
#  activation_22 (Activation)     (None, 28, 28, 336)  0           ['reduction_concat_stem_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 168)  0           ['adjust_conv_1_0[0][0]',
#                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)       (None, 28, 28, 168)  56448       ['activation_22[0][0]']
#
#  adjust_bn_0 (BatchNormalizatio  (None, 28, 28, 168)  672        ['concatenate_1[0][0]']
#  n)
#
#  normal_bn_1_0 (BatchNormalizat  (None, 28, 28, 168)  672        ['normal_conv_1_0[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 28, 28, 168)  0           ['normal_bn_1_0[0][0]']
#
#  activation_25 (Activation)     (None, 28, 28, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_27 (Activation)     (None, 28, 28, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_29 (Activation)     (None, 28, 28, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_31 (Activation)     (None, 28, 28, 168)  0           ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 28, 28, 168)  32424      ['activation_23[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 28, 28, 168)  29736      ['activation_25[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 28, 28, 168)  32424      ['activation_27[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 28, 28, 168)  29736      ['activation_29[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 28, 28, 168)  29736      ['activation_31[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_1_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 168)  672        ['separable_conv_1_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_1_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 168)  672        ['separable_conv_1_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_1_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  activation_24 (Activation)     (None, 28, 28, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  1_0[0][0]']
#
#  activation_26 (Activation)     (None, 28, 28, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  activation_28 (Activation)     (None, 28, 28, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  2_0[0][0]']
#
#  activation_30 (Activation)     (None, 28, 28, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  activation_32 (Activation)     (None, 28, 28, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  5_0[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 28, 28, 168)  32424      ['activation_24[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 28, 28, 168)  29736      ['activation_26[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 28, 28, 168)  32424      ['activation_28[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 28, 28, 168)  29736      ['activation_30[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 28, 28, 168)  29736      ['activation_32[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_2_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 168)  672        ['separable_conv_2_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_2_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 168)  672        ['separable_conv_2_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  normal_left3_0 (AveragePooling  (None, 28, 28, 168)  0          ['normal_bn_1_0[0][0]']
#  2D)
#
#  normal_left4_0 (AveragePooling  (None, 28, 28, 168)  0          ['adjust_bn_0[0][0]']
#  2D)
#
#  normal_right4_0 (AveragePoolin  (None, 28, 28, 168)  0          ['adjust_bn_0[0][0]']
#  g2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 168)  672        ['separable_conv_2_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  normal_add_1_0 (Add)           (None, 28, 28, 168)  0           ['separable_conv_2_bn_normal_left
#                                                                  1_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_0[0][0]']
# ...
#
#  normal_add_5_17 (Add)          (None, 7, 7, 672)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_17[0][0]',
#                                                                   'normal_bn_1_17[0][0]']
#
#  normal_concat_17 (Concatenate)  (None, 7, 7, 4032)  0           ['adjust_bn_17[0][0]',
#                                                                   'normal_add_1_17[0][0]',
#                                                                   'normal_add_2_17[0][0]',
#                                                                   'normal_add_3_17[0][0]',
#                                                                   'normal_add_4_17[0][0]',
#                                                                   'normal_add_5_17[0][0]']
#
#  activation_247 (Activation)    (None, 7, 7, 4032)   0           ['normal_concat_16[0][0]']
#
#  activation_248 (Activation)    (None, 7, 7, 4032)   0           ['normal_concat_17[0][0]']
#
#  adjust_conv_projection_18 (Con  (None, 7, 7, 672)   2709504     ['activation_247[0][0]']
#  v2D)
#
#  normal_conv_1_18 (Conv2D)      (None, 7, 7, 672)    2709504     ['activation_248[0][0]']
#
#  adjust_bn_18 (BatchNormalizati  (None, 7, 7, 672)   2688        ['adjust_conv_projection_18[0][0]
#  on)                                                             ']
#
#  normal_bn_1_18 (BatchNormaliza  (None, 7, 7, 672)   2688        ['normal_conv_1_18[0][0]']
#  tion)
#
#  activation_249 (Activation)    (None, 7, 7, 672)    0           ['normal_bn_1_18[0][0]']
#
#  activation_251 (Activation)    (None, 7, 7, 672)    0           ['adjust_bn_18[0][0]']
#
#  activation_253 (Activation)    (None, 7, 7, 672)    0           ['adjust_bn_18[0][0]']
#
#  activation_255 (Activation)    (None, 7, 7, 672)    0           ['adjust_bn_18[0][0]']
#
#  activation_257 (Activation)    (None, 7, 7, 672)    0           ['normal_bn_1_18[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 7, 7, 672)   468384      ['activation_249[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 7, 7, 672)   457632      ['activation_251[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 7, 7, 672)   468384      ['activation_253[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 7, 7, 672)   457632      ['activation_255[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 7, 7, 672)   457632      ['activation_257[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_1_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 672)   2688        ['separable_conv_1_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_1_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 672)   2688        ['separable_conv_1_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_1_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  activation_250 (Activation)    (None, 7, 7, 672)    0           ['separable_conv_1_bn_normal_left
#                                                                  1_18[0][0]']
#
#  activation_252 (Activation)    (None, 7, 7, 672)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  activation_254 (Activation)    (None, 7, 7, 672)    0           ['separable_conv_1_bn_normal_left
#                                                                  2_18[0][0]']
#
#  activation_256 (Activation)    (None, 7, 7, 672)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  activation_258 (Activation)    (None, 7, 7, 672)    0           ['separable_conv_1_bn_normal_left
#                                                                  5_18[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 7, 7, 672)   468384      ['activation_250[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 7, 7, 672)   457632      ['activation_252[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 7, 7, 672)   468384      ['activation_254[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 7, 7, 672)   457632      ['activation_256[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 7, 7, 672)   457632      ['activation_258[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_2_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 672)   2688        ['separable_conv_2_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_2_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 672)   2688        ['separable_conv_2_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#
#  normal_left3_18 (AveragePoolin  (None, 7, 7, 672)   0           ['normal_bn_1_18[0][0]']
#  g2D)
#
#  normal_left4_18 (AveragePoolin  (None, 7, 7, 672)   0           ['adjust_bn_18[0][0]']
#  g2D)
#
#  normal_right4_18 (AveragePooli  (None, 7, 7, 672)   0           ['adjust_bn_18[0][0]']
#  ng2D)
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 672)   2688        ['separable_conv_2_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  normal_add_1_18 (Add)          (None, 7, 7, 672)    0           ['separable_conv_2_bn_normal_left
#                                                                  1_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  normal_add_2_18 (Add)          (None, 7, 7, 672)    0           ['separable_conv_2_bn_normal_left
#                                                                  2_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  normal_add_3_18 (Add)          (None, 7, 7, 672)    0           ['normal_left3_18[0][0]',
#                                                                   'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)          (None, 7, 7, 672)    0           ['normal_left4_18[0][0]',
#                                                                   'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)          (None, 7, 7, 672)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_18[0][0]',
#                                                                   'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concatenate)  (None, 7, 7, 4032)  0           ['adjust_bn_18[0][0]',
#                                                                   'normal_add_1_18[0][0]',
#                                                                   'normal_add_2_18[0][0]',
#                                                                   'normal_add_3_18[0][0]',
#                                                                   'normal_add_4_18[0][0]',
#                                                                   'normal_add_5_18[0][0]']
#
#  activation_259 (Activation)    (None, 7, 7, 4032)   0           ['normal_concat_18[0][0]']
#
#  global_average_pooling2d (Glob  (None, 4032)        0           ['activation_259[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          516224      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 7)            903         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 85,433,945
# Trainable params: 517,127
# Non-trainable params: 84,916,818
# __________________________________________________________________________________________________

# %%
history = model.fit(train_data,
                 epochs=EPOCH,             
                 validation_data=validation_data,
                 callbacks=[restore_best],
                 shuffle= False)
# Out:
# Epoch 1/20
# 2054/2054 [==============================] - ETA: 0s - loss: 1.1442 - accuracy: 0.5656 - precision: 0.7191 - recall: 0.3954 - f1_score: 0.5102 - auc: 0.8890Model weights updated at epoch 1 with val_accuracy: 0.6056
# 2054/2054 [==============================] - 635s 301ms/step - loss: 1.1442 - accuracy: 0.5656 - precision: 0.7191 - recall: 0.3954 - f1_score: 0.5102 - auc: 0.8890 - val_loss: 1.0434 - val_accuracy: 0.6056 - val_precision: 0.7529 - val_recall: 0.4392 - val_f1_score: 0.5548 - val_auc: 0.9082
# Epoch 2/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.9426 - accuracy: 0.6422 - precision: 0.7574 - recall: 0.5126 - f1_score: 0.6114 - auc: 0.9252Model weights updated at epoch 2 with val_accuracy: 0.6323
# 2054/2054 [==============================] - 609s 297ms/step - loss: 0.9426 - accuracy: 0.6422 - precision: 0.7574 - recall: 0.5126 - f1_score: 0.6114 - auc: 0.9252 - val_loss: 0.9748 - val_accuracy: 0.6323 - val_precision: 0.7728 - val_recall: 0.4875 - val_f1_score: 0.5979 - val_auc: 0.9197
# Epoch 3/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.8693 - accuracy: 0.6685 - precision: 0.7706 - recall: 0.5593 - f1_score: 0.6481 - auc: 0.9364Model weights updated at epoch 3 with val_accuracy: 0.6471
# 2054/2054 [==============================] - 612s 298ms/step - loss: 0.8693 - accuracy: 0.6685 - precision: 0.7706 - recall: 0.5593 - f1_score: 0.6481 - auc: 0.9364 - val_loss: 0.9177 - val_accuracy: 0.6471 - val_precision: 0.7709 - val_recall: 0.5230 - val_f1_score: 0.6232 - val_auc: 0.9291
# Epoch 4/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.8153 - accuracy: 0.6904 - precision: 0.7859 - recall: 0.5892 - f1_score: 0.6735 - auc: 0.9439Model weights updated at epoch 4 with val_accuracy: 0.6677
# 2054/2054 [==============================] - 620s 302ms/step - loss: 0.8153 - accuracy: 0.6904 - precision: 0.7859 - recall: 0.5892 - f1_score: 0.6735 - auc: 0.9439 - val_loss: 0.8863 - val_accuracy: 0.6677 - val_precision: 0.7741 - val_recall: 0.5535 - val_f1_score: 0.6455 - val_auc: 0.9340
# Epoch 5/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.7827 - accuracy: 0.7031 - precision: 0.7914 - recall: 0.6075 - f1_score: 0.6874 - auc: 0.9483Model weights updated at epoch 5 with val_accuracy: 0.6798
# 2054/2054 [==============================] - 616s 300ms/step - loss: 0.7827 - accuracy: 0.7031 - precision: 0.7914 - recall: 0.6075 - f1_score: 0.6874 - auc: 0.9483 - val_loss: 0.8518 - val_accuracy: 0.6798 - val_precision: 0.7791 - val_recall: 0.5770 - val_f1_score: 0.6630 - val_auc: 0.9388
# Epoch 6/20
# 2054/2054 [==============================] - 612s 298ms/step - loss: 0.7616 - accuracy: 0.7081 - precision: 0.7940 - recall: 0.6202 - f1_score: 0.6964 - auc: 0.9510 - val_loss: 0.8655 - val_accuracy: 0.6748 - val_precision: 0.7746 - val_recall: 0.5721 - val_f1_score: 0.6581 - val_auc: 0.9373
# Epoch 7/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.7306 - accuracy: 0.7192 - precision: 0.8006 - recall: 0.6395 - f1_score: 0.7110 - auc: 0.9547Model weights updated at epoch 7 with val_accuracy: 0.7024
# 2054/2054 [==============================] - 614s 299ms/step - loss: 0.7306 - accuracy: 0.7192 - precision: 0.8006 - recall: 0.6395 - f1_score: 0.7110 - auc: 0.9547 - val_loss: 0.8084 - val_accuracy: 0.7024 - val_precision: 0.7965 - val_recall: 0.5999 - val_f1_score: 0.6843 - val_auc: 0.9450
# Epoch 8/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.7263 - precision: 0.8064 - recall: 0.6450 - f1_score: 0.7168 - auc: 0.9562Model weights updated at epoch 8 with val_accuracy: 0.7069
# 2054/2054 [==============================] - 619s 301ms/step - loss: 0.7192 - accuracy: 0.7263 - precision: 0.8064 - recall: 0.6450 - f1_score: 0.7168 - auc: 0.9562 - val_loss: 0.7924 - val_accuracy: 0.7069 - val_precision: 0.7934 - val_recall: 0.6173 - val_f1_score: 0.6944 - val_auc: 0.9468
# Epoch 9/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.7302 - precision: 0.8074 - recall: 0.6520 - f1_score: 0.7214 - auc: 0.9576Model weights updated at epoch 9 with val_accuracy: 0.7075
# 2054/2054 [==============================] - 613s 298ms/step - loss: 0.7058 - accuracy: 0.7302 - precision: 0.8074 - recall: 0.6520 - f1_score: 0.7214 - auc: 0.9576 - val_loss: 0.7925 - val_accuracy: 0.7075 - val_precision: 0.7966 - val_recall: 0.6206 - val_f1_score: 0.6977 - val_auc: 0.9470
# Epoch 10/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7391 - precision: 0.8131 - recall: 0.6613 - f1_score: 0.7294 - auc: 0.9601Model weights updated at epoch 10 with val_accuracy: 0.7110
# 2054/2054 [==============================] - 613s 298ms/step - loss: 0.6852 - accuracy: 0.7391 - precision: 0.8131 - recall: 0.6613 - f1_score: 0.7294 - auc: 0.9601 - val_loss: 0.7808 - val_accuracy: 0.7110 - val_precision: 0.7992 - val_recall: 0.6179 - val_f1_score: 0.6969 - val_auc: 0.9484
# Epoch 11/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.7446 - precision: 0.8169 - recall: 0.6721 - f1_score: 0.7374 - auc: 0.9617Model weights updated at epoch 11 with val_accuracy: 0.7299
# 2054/2054 [==============================] - 641s 312ms/step - loss: 0.6707 - accuracy: 0.7446 - precision: 0.8169 - recall: 0.6721 - f1_score: 0.7374 - auc: 0.9617 - val_loss: 0.7313 - val_accuracy: 0.7299 - val_precision: 0.8155 - val_recall: 0.6477 - val_f1_score: 0.7220 - val_auc: 0.9547
# Epoch 12/20
# 2054/2054 [==============================] - 624s 304ms/step - loss: 0.6678 - accuracy: 0.7455 - precision: 0.8199 - recall: 0.6743 - f1_score: 0.7400 - auc: 0.9620 - val_loss: 0.7798 - val_accuracy: 0.7114 - val_precision: 0.7844 - val_recall: 0.6386 - val_f1_score: 0.7041 - val_auc: 0.9492
# Epoch 13/20
# 2054/2054 [==============================] - 629s 306ms/step - loss: 0.6496 - accuracy: 0.7546 - precision: 0.8205 - recall: 0.6868 - f1_score: 0.7477 - auc: 0.9640 - val_loss: 0.7252 - val_accuracy: 0.7258 - val_precision: 0.7978 - val_recall: 0.6604 - val_f1_score: 0.7226 - val_auc: 0.9552
# Epoch 14/20
# 2054/2054 [==============================] - 626s 305ms/step - loss: 0.6411 - accuracy: 0.7563 - precision: 0.8258 - recall: 0.6916 - f1_score: 0.7527 - auc: 0.9649 - val_loss: 0.7353 - val_accuracy: 0.7264 - val_precision: 0.8019 - val_recall: 0.6593 - val_f1_score: 0.7236 - val_auc: 0.9542
# Epoch 15/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.6296 - accuracy: 0.7615 - precision: 0.8266 - recall: 0.6955 - f1_score: 0.7554 - auc: 0.9661Model weights updated at epoch 15 with val_accuracy: 0.7311
# 2054/2054 [==============================] - 614s 299ms/step - loss: 0.6296 - accuracy: 0.7615 - precision: 0.8266 - recall: 0.6955 - f1_score: 0.7554 - auc: 0.9661 - val_loss: 0.7305 - val_accuracy: 0.7311 - val_precision: 0.7973 - val_recall: 0.6640 - val_f1_score: 0.7246 - val_auc: 0.9551
# Epoch 16/20
# 2054/2054 [==============================] - 612s 298ms/step - loss: 0.6289 - accuracy: 0.7599 - precision: 0.8239 - recall: 0.6957 - f1_score: 0.7544 - auc: 0.9662 - val_loss: 0.7361 - val_accuracy: 0.7278 - val_precision: 0.7921 - val_recall: 0.6685 - val_f1_score: 0.7251 - val_auc: 0.9545
# Epoch 17/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.7644 - precision: 0.8277 - recall: 0.7035 - f1_score: 0.7606 - auc: 0.9673Model weights updated at epoch 17 with val_accuracy: 0.7338
# 2054/2054 [==============================] - 616s 300ms/step - loss: 0.6177 - accuracy: 0.7644 - precision: 0.8277 - recall: 0.7035 - f1_score: 0.7606 - auc: 0.9673 - val_loss: 0.7371 - val_accuracy: 0.7338 - val_precision: 0.8062 - val_recall: 0.6666 - val_f1_score: 0.7298 - val_auc: 0.9541
# Epoch 18/20
# 2054/2054 [==============================] - 623s 303ms/step - loss: 0.6013 - accuracy: 0.7701 - precision: 0.8319 - recall: 0.7092 - f1_score: 0.7657 - auc: 0.9690 - val_loss: 0.7434 - val_accuracy: 0.7309 - val_precision: 0.7966 - val_recall: 0.6677 - val_f1_score: 0.7265 - val_auc: 0.9539
# Epoch 19/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.6040 - accuracy: 0.7698 - precision: 0.8322 - recall: 0.7097 - f1_score: 0.7661 - auc: 0.9687Model weights updated at epoch 19 with val_accuracy: 0.7415
# 2054/2054 [==============================] - 624s 304ms/step - loss: 0.6040 - accuracy: 0.7698 - precision: 0.8322 - recall: 0.7097 - f1_score: 0.7661 - auc: 0.9687 - val_loss: 0.6993 - val_accuracy: 0.7415 - val_precision: 0.8084 - val_recall: 0.6714 - val_f1_score: 0.7335 - val_auc: 0.9586
# Epoch 20/20
# 2054/2054 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.7717 - precision: 0.8317 - recall: 0.7118 - f1_score: 0.7671 - auc: 0.9694Model weights updated at epoch 20 with val_accuracy: 0.7460
# 2054/2054 [==============================] - 615s 299ms/step - loss: 0.5959 - accuracy: 0.7717 - precision: 0.8317 - recall: 0.7118 - f1_score: 0.7671 - auc: 0.9694 - val_loss: 0.6904 - val_accuracy: 0.7460 - val_precision: 0.8111 - val_recall: 0.6838 - val_f1_score: 0.7420 - val_auc: 0.9596
# Restoring model weights from best epoch 20 with val_accuracy: 0.7460

# %%
model.save(f"{model_name}.keras")

# %%
# Save history
with open(f'{model_name} training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# Load history
with open(f'{model_name} training_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
epochs = range(1, len(history['loss']) + 1)

# Training and validation metrics
tr_loss = history['loss']
val_loss = history['val_loss']
tr_acc = history['accuracy']
val_acc = history['val_accuracy']
tr_precision = history['precision']
val_precision = history['val_precision']
tr_auc = history['auc']
val_auc = history['val_auc']
tr_f1 = history['f1_score']
val_f1 = history['val_f1_score']

# %%
def print_best_metrics(metric_name, train, val):
    best_epoch = np.argmax(val) + 1
    print(f"📌 Best {metric_name} at epoch {best_epoch}:")
    print(f"   - Train {metric_name}: {abs(train[best_epoch - 1]):.4f}")
    print(f"   - Val {metric_name}:   {abs(val[best_epoch - 1]):.4f}\n")
    return {
        "epoch": best_epoch,
        "train": float(f"{abs(train[best_epoch - 1]):.4f}"),
        "val": float(f"{abs(val[best_epoch - 1]):.4f}")
    }

# Get best metrics
accuracy_summary = print_best_metrics("Accuracy", tr_acc, val_acc)
precision_summary = print_best_metrics("Precision", tr_precision, val_precision)
auc_summary = print_best_metrics("AUC", tr_auc, val_auc)
f1_summary = print_best_metrics("F1 Score", tr_f1, val_f1)
loss_summary = print_best_metrics("Loss", [-x for x in tr_loss], [-x for x in val_loss])  # invert for max search

# Final summary dictionary
summary_dict = {
    model_name: {
        "Accuracy": accuracy_summary,
        "Precision": precision_summary,
        "AUC": auc_summary,
        "F1 Score": f1_summary,
        "Loss": loss_summary,
    }
}

# Print summary
print("📊 Model Summary:")
print(summary_dict)
# Out:
# 📌 Best Accuracy at epoch 20:
#    - Train Accuracy: 0.7717
#    - Val Accuracy:   0.7460
#
# 📌 Best Precision at epoch 11:
#    - Train Precision: 0.8169
#    - Val Precision:   0.8155
#
# 📌 Best AUC at epoch 20:
#    - Train AUC: 0.9694
#    - Val AUC:   0.9596
#
# 📌 Best F1 Score at epoch 20:
#    - Train F1 Score: 0.7671
#    - Val F1 Score:   0.7420
#
# 📌 Best Loss at epoch 20:
#    - Train Loss: 0.5959
#    - Val Loss:   0.6904
#
# 📊 Model Summary:
# {'NASNetLarge': {'Accuracy': {'epoch': 20, 'train': 0.7717, 'val': 0.746}, 'Precision': {'epoch': 11, 'train': 0.8169, 'val': 0.8155}, 'AUC': {'epoch': 20, 'train': 0.9694, 'val': 0.9596}, 'F1 Score': {'epoch': 20, 'train': 0.7671, 'val': 0.742}, 'Loss': {'epoch': 20, 'train': 0.5959, 'val': 0.6904}}}

# %%
best_epoch_loss = np.argmin(val_loss)
best_val_loss = val_loss[best_epoch_loss]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_loss, color='red', label='Training Loss', linewidth=2)
plt.plot(epochs, val_loss, color='green', label='Validation Loss', linestyle='--', linewidth=2)
plt.scatter(best_epoch_loss + 1, best_val_loss, s=150, c='blue',
            label=f'Best epoch = {best_epoch_loss + 1}', edgecolors='black')
plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_acc = np.argmax(val_acc)
best_val_acc = val_acc[best_epoch_acc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_acc, color='red', label='Training Accuracy', linewidth=2)
plt.plot(epochs, val_acc, color='green', label='Validation Accuracy', linestyle='--', linewidth=2)
plt.scatter(best_epoch_acc + 1, best_val_acc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_acc + 1}', edgecolors='black')
plt.title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_prec = np.argmax(val_precision)
best_val_prec = val_precision[best_epoch_prec]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_precision, color='red', label='Training Precision', linewidth=2)
plt.plot(epochs, val_precision, color='green', label='Validation Precision', linestyle='--', linewidth=2)
plt.scatter(best_epoch_prec + 1, best_val_prec, s=150, c='blue',
            label=f'Best epoch = {best_epoch_prec + 1}', edgecolors='black')
plt.title('Training and Validation Precision', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_f1 = np.argmax(val_f1)
best_val_f1 = val_f1[best_epoch_f1]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_f1, color='red', label='Training F1 Score', linewidth=2)
plt.plot(epochs, val_f1, color='green', label='Validation F1 Score', linestyle='--', linewidth=2)
plt.scatter(best_epoch_f1 + 1, best_val_f1, s=150, c='blue',
            label=f'Best epoch = {best_epoch_f1 + 1}', edgecolors='black')
plt.title('Training and Validation F1 Score', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('F1 Score', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_auc = np.argmax(val_auc)
best_val_auc = val_auc[best_epoch_auc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_auc, color='red', label='Training AUC', linewidth=2)
plt.plot(epochs, val_auc, color='green', label='Validation AUC', linestyle='--', linewidth=2)
plt.scatter(best_epoch_auc + 1, best_val_auc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_auc + 1}', edgecolors='black')
plt.title('Training and Validation AUC', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
def evaluate_model(model, test_data, labels, model_name, test_dataframe, batch_size=BATCH_SIZE):
    """
    Evaluate a trained Keras model using a test data generator.

    Args:
        model (Model): Trained Keras model.
        test_data (Iterator): A Keras data generator for testing.
        labels (List[str]): Class label names.
        model_name (str): Name of the model (for display).
        test_dataframe (pd.DataFrame): DataFrame with test samples (for step calculation).
        batch_size (int): Batch size used in the test_data generator.

    Returns:
        Tuple[dict, dict]: 
            - Dictionary containing accuracy, precision, recall, F1 score, and AUC.
            - Dictionary of AUC curve data {class_label: (fpr, tpr)} for ROC plotting.
    """
    import math
    import numpy as np
    from sklearn.metrics import (
        accuracy_score, precision_score, recall_score, f1_score,
        roc_auc_score, roc_curve, classification_report, confusion_matrix
    )
    import matplotlib.pyplot as plt
    import seaborn as sns

    # Calculate steps needed for full evaluation
    steps = math.ceil(len(test_dataframe) / batch_size)

    y_true = []
    y_pred = []
    y_probs = []

    # Loop through batches and collect predictions and true labels
    for _ in tqdm(range(steps), desc=f"Evaluating {model_name}"):
        images, labels_batch = next(test_data)

        preds = model.predict(images, verbose=0)            # Predicted probabilities
        y_probs.extend(preds)                               # Save for AUC

        y_pred.extend(np.argmax(preds, axis=-1))            # Predicted class indices
        y_true.extend(np.argmax(labels_batch, axis=-1))     # True class indices

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_probs = np.array(y_probs)

    # Calculate performance metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average="weighted")
    recall = recall_score(y_true, y_pred, average="weighted")
    f1 = f1_score(y_true, y_pred, average="weighted")

    try:
        auc = roc_auc_score(y_true, y_probs, multi_class='ovr', average='weighted')
    except ValueError:
        auc = float('nan')

    # Generate classification report
    report = classification_report(y_true, y_pred, target_names=labels)

    # Print summary metrics
    print(f"--- {model_name} ---")
    print(f"Accuracy : {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1 Score : {f1:.4f}")
    print(f"AUC      : {auc:.4f}\n")
    print("Classification Report:\n")
    print(report)

    # Plot confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=labels, yticklabels=labels,
        annot_kws={'size': 14}, cbar=True, linewidths=0.5, linecolor='gray',
        cbar_kws={'shrink': 0.8}
    )
    plt.title(f'Confusion Matrix: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=12, rotation=45 if len(labels) > 10 else 0)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

    # Compute ROC curve data per class
    auc_curve_data = {}
    try:
        for i, label in enumerate(labels):
            fpr, tpr, _ = roc_curve((y_true == i).astype(int), y_probs[:, i])
            auc_curve_data[label] = (fpr, tpr)
    except Exception:
        auc_curve_data = {}

    return {
        "model_name": model_name,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "auc": auc
    }, auc_curve_data

# %%
results, auc_curve_data = evaluate_model(model, test_data, labels, model_name, test_dataframe)
# Out:
# Evaluating NASNetLarge: 100%|██████████| 294/294 [02:02<00:00,  2.39it/s]
# --- NASNetLarge ---
# Accuracy : 0.7524
# Precision: 0.7502
# Recall   : 0.7524
# F1 Score : 0.7484
# AUC      : 0.9563
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        akiec       0.66      0.80      0.72       670
#          bcc       0.77      0.72      0.74       670
#          bkl       0.66      0.53      0.59       671
#           df       0.81      0.92      0.86       671
#          mel       0.64      0.58      0.61       671
#           nv       0.78      0.77      0.78       670
#         vasc       0.94      0.94      0.94       671
#
#     accuracy                           0.75      4694
#    macro avg       0.75      0.75      0.75      4694
# weighted avg       0.75      0.75      0.75      4694

# %%
# Plotting the ROC curve
for label, (fpr, tpr) in auc_curve_data.items():
    plt.plot(fpr, tpr, label=f'ROC curve ({label})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve of {model_name}')
plt.legend()
plt.grid(True)
plt.show()
